# %% [markdown]
# <div style="text-align: center; line-height: 0; padding-top: 9px;">
#   <img
#     src="https://databricks.com/wp-content/uploads/2018/03/db-academy-rgb-1200px.png"
#     alt="Databricks Learning"
#   >
# </div>

# %% [markdown]
# # Lab - Load and Explore Data
#
# In this lab, you will build hands-on experience working with data in a Databricks environment using PySpark. You will load data, explore its structure, compute summary statistics, and use **Genie Code** to generate visualizations that support machine learning workflows.
#
# You will also work with Delta Lake to manage data, control access, and explore versioned data using time travel.
#
# **Lab Objectives**
#
# In this lab, you will:
#
# 1. Load data from a CSV file and store it as a Delta table
# 2. Manage access permissions on a Delta table
# 3. Compute and interpret summary statistics
# 4. Use **Genie Code** to explore the dataset, including:
#    - Assessing class balance and target distribution
#    - Identifying missing value patterns
#    - Exploring feature distributions
#    - Comparing key features against the target variable
# 5. Modify the dataset by removing a column
# 6. Use Delta Lake time travel to access a previous version of the data
# 7. View and interpret the version history of a Delta table

# %% [markdown]
# ## REQUIRED - SELECT A COMPUTE ENVIRONMENT
#
# <div style="border-left: 4px solid #F44336; background: #FFEBEE; padding: 16px 20px; border-radius: 4px; margin: 16px 0;">
# <div style="display: flex; align-items: flex-start; gap: 12px;">
# <div>
# <strong style="color: #C62828; font-size: 1.1em;">Select Compute</strong>
# <p style="margin: 8px 0 0 0; color: #333;">Before starting this notebook, select the required compute environment listed below.</p>
# <ul style="margin: 12px 0 0 16px; color: #333;">
# <li><strong>Serverless Compute, Version 5</strong> — <a href="https://docs.databricks.com/aws/en/compute/serverless/dependencies#-select-an-environment-version" style="color: #1976D2; text-decoration: underline;">How to select an environment version</a></li>
# </ul>
# <p style="margin: 8px 0 0 0; color: #333;"><strong>NOTE:</strong> This notebook was <strong>developed and tested using Serverless V5</strong>. Other compute options may work but are not guaranteed to behave the same or support all features demonstrated.</p>
# </div>
# </div>
# </div>

# %% [markdown]
# ### Classroom Setup
# Run the following cell to configure your working environment for this course.
#
# This setup will:
# - Initialize the `DA` object (Databricks Academy helper)
# - Configure your **default catalog** and **schema**
# - Provision any supporting configuration needed for this demo
#
# **NOTE:** The `DA` object is only available in Databricks Academy courses.

# %%
# %run ../Includes/Classroom-Setup-1.2

# %% [markdown]
# **Other Conventions:**
#
# Throughout this lab, we'll make use of the object `DA`, which provides critical variables. Execute the code block below to see various variables that will be used in this notebook:

# %%
print(f"Username:          {DA.username}")
print(f"Catalog Name:      {DA.catalog_name}")
print(f"Schema Name:       {DA.schema_name}")
print(f"Working Directory: {DA.paths.working_dir}")
print(f"Dataset Location:  {DA.paths.datasets}")

# %% [markdown]
# ## Task 1: Read Data from Delta Table
#
#
# + Use Spark to read the CSV file and write it as a Delta table into a DataFrame.

# %%
## Load dataset with spark
shared_volume_name = 'telco' ## From Marketplace
csv_name = 'telco-customer-churn-missing' ## CSV file name
dataset_path = f"{DA.paths.datasets.telco}/{shared_volume_name}/{csv_name}.csv" ## Full path

## Read dataset with spark
telco_df = <FILL_IN>

table_name = "telco_missing"
table_name_bronze = f"{table_name}_bronze"

## Write it as delta table
telco_df.write.<FILL_IN>
telco_df.show()

# %% [markdown]
# ##### Task 1: Read Data from Delta Table — Solution
# <details>
# <summary>EXPAND FOR SOLUTION CODE</summary>
# <button onclick="copyAns1()" style="background:#1976d2; color:white; border:none; padding:6px 12px; border-radius:4px; cursor:pointer; font-weight:600; margin: 8px 0;">Copy to clipboard</button>
#
# <pre id="copy-ans-1" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.35; white-space:pre;">
# <code>
# ## Load dataset with spark
# shared_volume_name = 'telco'
# csv_name = 'telco-customer-churn-missing'
# dataset_path = f"{DA.paths.datasets.telco}/{shared_volume_name}/{csv_name}.csv"
#
# ## Read dataset with spark
# telco_df = spark.read.csv(dataset_path, header="true", inferSchema="true", multiLine="true", escape='"')
#
# table_name = "telco_missing"
# table_name_bronze = f"{table_name}_bronze"
#
# ## Write it as delta table
# telco_df.write.mode("overwrite").option("overwriteSchema", True).saveAsTable(table_name_bronze)
# telco_df.show()
# </code></pre>
#
# <script>
# function copyAns1() {
#   const el = document.getElementById("copy-ans-1");
#   if (!el) return;
#   const text = el.innerText;
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text).then(() => alert("Copied to clipboard")).catch(err => fallbackAns1(text));
#   } else { fallbackAns1(text); }
# }
# function fallbackAns1(text) {
#   const ta = document.createElement("textarea");
#   ta.value = text; ta.style.position = "fixed"; ta.style.left = "-9999px";
#   document.body.appendChild(ta); ta.select();
#   try { document.execCommand("copy"); alert("Copied to clipboard"); }
#   catch (e) { alert("Could not copy. Please copy manually."); }
#   finally { document.body.removeChild(ta); }
# }
# </script>
# </details>

# %% [markdown]
# ## Task 2: Manage Data Permissions
#
# Establish controlled access to the Telco Delta table by granting specific permissions for essential actions.
#
# + Grant permissions for specific actions (e.g., read) on the Delta table.

# %%
# %sql
---- Write query to Grant Permission to all the users to access Delta Table
<FILL_IN>;

# %% [markdown]
# ##### Task 2: Manage Data Permissions — Solution
# <details>
# <summary>EXPAND FOR SOLUTION CODE</summary>
# <button onclick="copyAns2()" style="background:#1976d2; color:white; border:none; padding:6px 12px; border-radius:4px; cursor:pointer; font-weight:600; margin: 8px 0;">Copy to clipboard</button>
#
# <pre id="copy-ans-2" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.35; white-space:pre;">
# <code>
# %sql
# GRANT SELECT ON TABLE telco_missing_bronze TO `account users`;
# </code></pre>
#
# <script>
# function copyAns2() {
#   const el = document.getElementById("copy-ans-2");
#   if (!el) return;
#   const text = el.innerText;
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text).then(() => alert("Copied to clipboard")).catch(err => fallbackAns2(text));
#   } else { fallbackAns2(text); }
# }
# function fallbackAns2(text) {
#   const ta = document.createElement("textarea");
#   ta.value = text; ta.style.position = "fixed"; ta.style.left = "-9999px";
#   document.body.appendChild(ta); ta.select();
#   try { document.execCommand("copy"); alert("Copied to clipboard"); }
#   catch (e) { alert("Could not copy. Please copy manually."); }
#   finally { document.body.removeChild(ta); }
# }
# </script>
# </details>

# %% [markdown]
# ## Task 3: Show Summary Statistics
#
# Compute and present key statistical metrics to gain a comprehensive understanding of the Telco dataset.
#
# + Use PySpark to compute and display summary statistics for the Telco dataset.
# + Include key metrics such as mean, standard deviation, min, max, and more.

# %%
## Show summary of the Data
<FILL_IN>

# %% [markdown]
# ##### Task 3: Show Summary Statistics — Solution
# <details>
# <summary>EXPAND FOR SOLUTION CODE</summary>
# <button onclick="copyAns3()" style="background:#1976d2; color:white; border:none; padding:6px 12px; border-radius:4px; cursor:pointer; font-weight:600; margin: 8px 0;">Copy to clipboard</button>
#
# <pre id="copy-ans-3" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.35; white-space:pre;">
# <code>
# ## Show summary of the Data
# display(telco_df.summary())
# </code></pre>
#
# <script>
# function copyAns3() {
#   const el = document.getElementById("copy-ans-3");
#   if (!el) return;
#   const text = el.innerText;
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text).then(() => alert("Copied to clipboard")).catch(err => fallbackAns3(text));
#   } else { fallbackAns3(text); }
# }
# function fallbackAns3(text) {
#   const ta = document.createElement("textarea");
#   ta.value = text; ta.style.position = "fixed"; ta.style.left = "-9999px";
#   document.body.appendChild(ta); ta.select();
#   try { document.execCommand("copy"); alert("Copied to clipboard"); }
#   catch (e) { alert("Could not copy. Please copy manually."); }
#   finally { document.body.removeChild(ta); }
# }
# </script>
# </details>

# %% [markdown]
# ## Task 4: Explore the Dataset Using Genie Code
#
# In this task, you will use **Genie Code** to perform a guided exploratory analysis of the Telco dataset.
#
# Instead of writing code manually, you will provide a **single, well-structured prompt** and allow Genie Code to generate multiple steps of analysis. You may need to review, run, and refine the generated code as you proceed.
#
# The goal is to use Genie Code to understand:
# - the target variable (`Churn`)
# - missing data patterns
# - key feature relationships
# - potential signals useful for machine learning
#
# Run the cell below to display the dataset, then use the prompt that follows.

# %%
## Display the data — run this cell before using the Genie Code prompts below
display(telco_df)

# %% [markdown]
# ### Use Genie Code to Perform Exploratory Analysis
#
# **Copy the prompt below into Genie Code and execute it step by step.**
#
# <button id="copy-genie-btn-t4" onclick="copyGenieT4()" style="background:#ff6b3d; color:white; border:none; padding:8px 14px; border-radius:6px; cursor:pointer; font-weight:600;">
# Copy Genie Prompt
# </button>
#
# <pre id="copy-genie-t4" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.4; white-space:pre-wrap;">
# You are a data analyst working in a Databricks notebook.
#
# We have a Spark DataFrame called `telco_df`.
#
# Your task is to perform a structured exploratory data analysis for a machine learning use case (predicting customer churn).
#
# Follow these steps and generate code in separate cells:
#
# 1. Convert the Spark DataFrame to a pandas DataFrame called `telco_pdf`.
#
# 2. Analyze the target variable:
#    - Show the distribution of the `Churn` column
#    - Display both counts and percentages
#    - Comment on whether the dataset is balanced or imbalanced
#
# 3. Analyze missing values:
#    - Calculate the percentage of missing values per column
#    - Visualize the result using a bar chart
#    - Highlight columns with significant missing data
#
# 4. Explore feature relationships:
#    - Compare `MonthlyCharges` and `tenure` across churn categories using boxplots
#    - Identify any visible patterns between these features and churn
#
# 5. Explore categorical features:
#    - Analyze how `Contract` and `InternetService` relate to churn
#    - Use countplots or similar visualizations
#
# 6. Based on the analysis:
#    - Print a short summary of key insights that could be useful for building a machine learning model
#
# Use matplotlib or seaborn for visualizations.
# Keep the code clean and readable for learners.
# Display all charts inline.
#
# Break the output into multiple logical steps (multiple code cells if needed).
# </pre>
#
# <script>
# function copyGenieT4() {
#   const el = document.getElementById("copy-genie-t4");
#   const btn = document.getElementById("copy-genie-btn-t4");
#   if (!el || !btn) return;
#
#   const text = el.innerText;
#   const originalText = "Copy Genie Prompt";
#
#   function showCopied() {
#     btn.innerText = "✅ Copied";
#     setTimeout(() => {
#       btn.innerText = originalText;
#     }, 2000);
#   }
#
#   function fallbackGenieT4(text) {
#     const ta = document.createElement("textarea");
#     ta.value = text;
#     ta.style.position = "fixed";
#     ta.style.left = "-9999px";
#     document.body.appendChild(ta);
#     ta.select();
#     try {
#       document.execCommand("copy");
#       showCopied();
#     } catch (e) {
#       alert("Could not copy automatically. Please copy manually.");
#     } finally {
#       document.body.removeChild(ta);
#     }
#   }
#
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text)
#       .then(() => showCopied())
#       .catch(() => fallbackGenieT4(text));
#   } else {
#     fallbackGenieT4(text);
#   }
# }
# </script>

# %% [markdown]
# ## Task 5: Drop the Column
# Remove a specific column to enhance data cleanliness and focus.
#
# + Identify the column that needs to be dropped. For this task, drop the `SeniorCitizen` column.
#
# + Use the appropriate command to drop the identified column from the Telco dataset.
#
# + Verify that the column has been successfully dropped by displaying the updated dataset.

# %%
## Drop SeniorCitizen Column
telco_dropped_df = <FILL_IN>

## Overwrite the Delta table
telco_dropped_df.write.mode("overwrite")<FILL_IN>

# %% [markdown]
# ##### Task 5: Drop the Column — Solution
# <details>
# <summary>EXPAND FOR SOLUTION CODE</summary>
# <button onclick="copyAns5()" style="background:#1976d2; color:white; border:none; padding:6px 12px; border-radius:4px; cursor:pointer; font-weight:600; margin: 8px 0;">Copy to clipboard</button>
#
# <pre id="copy-ans-5" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.35; white-space:pre;">
# <code>
# ## Drop SeniorCitizen Column
# telco_dropped_df = telco_df.drop("SeniorCitizen")
#
# ## Overwrite the Delta table
# telco_dropped_df.write.mode("overwrite").option("overwriteSchema", True).saveAsTable(table_name_bronze)
# </code></pre>
#
# <script>
# function copyAns5() {
#   const el = document.getElementById("copy-ans-5");
#   if (!el) return;
#   const text = el.innerText;
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text).then(() => alert("Copied to clipboard")).catch(err => fallbackAns5(text));
#   } else { fallbackAns5(text); }
# }
# function fallbackAns5(text) {
#   const ta = document.createElement("textarea");
#   ta.value = text; ta.style.position = "fixed"; ta.style.left = "-9999px";
#   document.body.appendChild(ta); ta.select();
#   try { document.execCommand("copy"); alert("Copied to clipboard"); }
#   catch (e) { alert("Could not copy. Please copy manually."); }
#   finally { document.body.removeChild(ta); }
# }
# </script>
# </details>

# %% [markdown]
# ## Task 6: Time-Travel to First Version
#
# Revert the Telco dataset back to its initial state using Delta time-travel.
#
# + Utilize time-travel capabilities to revert the dataset to its initial version.
#
# + Display and analyze the first version of the Telco dataset to understand its original structure and content.

# %%
## Extract timestamp of first version (can also be set manually)
timestamp_v0 = spark.sql(<FILL_IN>)
(spark
        .read
        .option(<FILL_IN>)
        .table(<FILL_IN>)
        .printSchema()
)

# %% [markdown]
# ##### Task 6: Time-Travel to First Version — Solution
# <details>
# <summary>EXPAND FOR SOLUTION CODE</summary>
# <button onclick="copyAns6()" style="background:#1976d2; color:white; border:none; padding:6px 12px; border-radius:4px; cursor:pointer; font-weight:600; margin: 8px 0;">Copy to clipboard</button>
#
# <pre id="copy-ans-6" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.35; white-space:pre;">
# <code>
# ## Extract timestamp of first version
# timestamp_v0 = spark.sql(f"DESCRIBE HISTORY telco_missing_bronze").orderBy("version").first().timestamp
# (spark
#         .read
#         .option("timestampAsOf", timestamp_v0)
#         .table("telco_missing_bronze")
#         .printSchema()
# )
# </code></pre>
#
# <script>
# function copyAns6() {
#   const el = document.getElementById("copy-ans-6");
#   if (!el) return;
#   const text = el.innerText;
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text).then(() => alert("Copied to clipboard")).catch(err => fallbackAns6(text));
#   } else { fallbackAns6(text); }
# }
# function fallbackAns6(text) {
#   const ta = document.createElement("textarea");
#   ta.value = text; ta.style.position = "fixed"; ta.style.left = "-9999px";
#   document.body.appendChild(ta); ta.select();
#   try { document.execCommand("copy"); alert("Copied to clipboard"); }
#   catch (e) { alert("Could not copy. Please copy manually."); }
#   finally { document.body.removeChild(ta); }
# }
# </script>
# </details>

# %% [markdown]
# ## Task 7: Read Previous Versions of the Delta Table
# Demonstrate the ability to read data from a specific version of the Delta table.
#
# + Use SQL to display the full version history of the Delta table.

# %%
## Show table versions
<FILL_IN>

# %% [markdown]
# ##### Task 7: Read Previous Versions — Solution
# <details>
# <summary>EXPAND FOR SOLUTION CODE</summary>
# <button onclick="copyAns7()" style="background:#1976d2; color:white; border:none; padding:6px 12px; border-radius:4px; cursor:pointer; font-weight:600; margin: 8px 0;">Copy to clipboard</button>
#
# <pre id="copy-ans-7" style="font-family: ui-monospace, SFMono-Regular, Menlo, Monaco, Consolas, 'Liberation Mono', 'Courier New', monospace; border:1px solid #e5e7eb; border-radius:10px; background:#f8fafc; padding:14px 16px; font-size:0.85rem; line-height:1.35; white-space:pre;">
# <code>
# %sql
# DESCRIBE HISTORY telco_missing_bronze;
# </code></pre>
#
# <script>
# function copyAns7() {
#   const el = document.getElementById("copy-ans-7");
#   if (!el) return;
#   const text = el.innerText;
#   if (navigator.clipboard && navigator.clipboard.writeText) {
#     navigator.clipboard.writeText(text).then(() => alert("Copied to clipboard")).catch(err => fallbackAns7(text));
#   } else { fallbackAns7(text); }
# }
# function fallbackAns7(text) {
#   const ta = document.createElement("textarea");
#   ta.value = text; ta.style.position = "fixed"; ta.style.left = "-9999px";
#   document.body.appendChild(ta); ta.select();
#   try { document.execCommand("copy"); alert("Copied to clipboard"); }
#   catch (e) { alert("Could not copy. Please copy manually."); }
#   finally { document.body.removeChild(ta); }
# }
# </script>
# </details>

# %% [markdown]
# ## Conclusion
# In this lab, you demonstrated how to explore and manipulate the Telco dataset using Databricks, covering data loading, permissions management, summary statistics, ML-focused visualization with Genie Code, column management, and Delta time-travel capabilities. These foundational skills will carry directly into the data preparation and feature engineering modules ahead.

# %% [markdown]
# &copy; 2026 Databricks, Inc. All rights reserved. Apache, Apache Spark, Spark, the Spark Logo, Apache Iceberg, Iceberg, and the Apache Iceberg logo are trademarks of the <a href="https://www.apache.org/" target="_blank">Apache Software Foundation</a>.<br/><br/><a href="https://databricks.com/privacy-policy" target="_blank">Privacy Policy</a> | <a href="https://databricks.com/terms-of-use" target="_blank">Terms of Use</a> | <a href="https://help.databricks.com/" target="_blank">Support</a>
